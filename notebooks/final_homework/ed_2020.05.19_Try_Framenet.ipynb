# %%
import nltk

# %%
from nltk.corpus import framenet as fn

# %%
import nltk

# %%
nltk.download('framenet_v17')
# Out:
# [nltk_data] Downloading package framenet_v17 to
# [nltk_data]     /home/egor/nltk_data...
# [nltk_data]   Package framenet_v17 is already up-to-date!
# True

# %%
len(fn.frames())
# Out:
# 1221

# %%
fn.frames(r'(?i)medical')
# Out:
# [<frame ID=239 name=Medical_conditions>, <frame ID=257 name=Medical_instruments>, ...]

# %%
frame = fn.frames()[0]

# %%
for fr in fn.frames_by_lemma('work'):
    print(fr)
# Out:
# frame (282): Being_employed
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Being_employed.xml
#
# [definition]
#   An Employee has a Position doing work in a particular Field, or
#   doing work on a particular Task, for which an Employer gives
#   Compensation to the Employee.  ' Undocumented foreigners are
#   working as  building contractors for Laing Builders.'
#
# [semTypes] 0 semantic types
#
# [frameRelations] 5 frame relations
#   <Complex=Employee_scenario -- Subframe -> Component=Being_employed>
#   <Source=Being_employed -- ReFraming_Mapping -> Target=People_by_vocation>
#   <Earlier=Being_employed -- Precedes -> Later=Quitting>
#   <Earlier=Get_a_job -- Precedes -> Later=Being_employed>
#   <Neutral=Employment_continue -- Perspective_on -> Perspectivized=Being_employed>
#
# [lexUnit] 17 lexical units
#   at.prep (17471), clerk.v (5925), employ.n (5783), employed.a
#   (10533), employment.n (12590), farm (out).v (11947), job.n
# ...

# %%
frame.values()
# Out:
# dict_values(['KmG', '03/05/2008 03:50:35 PST Wed', 'Abandonment', 2031, 'frame', "An Agent leaves behind a Theme effectively rendering it no longer within their control or of the normal security as one's property.   'Carolyn abandoned her car and jumped on a red double decker bus.'  'Perhaps he left the key in the ignition'  'Abandonment of a child is considered to be a serious crime in many jurisdictions.'  There are also metaphorically used examples:  'She left her old ways behind .'", '<def-root>An <fex name="Agent">Agent</fex> leaves behind a <fex name="Theme">Theme</fex> effectively rendering it no longer within their control or of the normal security as one\'s property. \n\n<ex><fex name="Agent">Carolyn</fex> <t>abandoned</t> <fex name="Theme">her car</fex> and jumped on a red double decker bus.</ex>\n\n<ex>Perhaps <fex name="Agent">he</fex> <t>left</t> <fex name="Theme">the key</fex> in the ignition</ex>\n\n<ex><t>Abandonment</t> <fex name="Theme">of a child</fex> is considere
# ...

# %%
frame
# Out:
# frame (2031): Abandonment
#
# [URL] https://framenet2.icsi.berkeley.edu/fnReports/data/frame/Abandonment.xml
#
# [definition]
#   An Agent leaves behind a Theme effectively rendering it no longer
#   within their control or of the normal security as one's property.
#   'Carolyn abandoned her car and jumped on a red double decker
#   bus.'  'Perhaps he left the key in the ignition'  'Abandonment of
#   a child is considered to be a serious crime in many
#   jurisdictions.'  There are also metaphorically used examples:
#   'She left her old ways behind .'
#
# [semTypes] 0 semantic types
#
# [frameRelations] 1 frame relations
#   <Parent=Intentionally_affect -- Inheritance -> Child=Abandonment>
#
# [lexUnit] 5 lexical units
#   abandon.v (14839), abandoned.a (14843), abandonment.n (14842),
#   forget.v (15317), leave.v (14841)
#
#
# [FE] 12 frame elements
#             Core: Agent (12338), Theme (12339)
# ...
